# %%
pip install wordcloud matplotlib
# Out:
# Requirement already satisfied: wordcloud in c:\users\guna harshitha\anaconda3\lib\site-packages (1.9.4)
# Requirement already satisfied: matplotlib in c:\users\guna harshitha\anaconda3\lib\site-packages (3.7.0)
# Requirement already satisfied: pillow in c:\users\guna harshitha\anaconda3\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\guna harshitha\anaconda3\lib\site-packages (from wordcloud) (1.24.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\guna harshitha\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: six>=1.5 in c:\users\guna harshitha\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Input text
text = "data science machine learning artificial intelligence"

# Generate WordCloud
wordcloud = WordCloud(width=800, height=400, background_color="white").generate(text)

# Display the WordCloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")  # Hide axes
plt.show()

# Save the WordCloud as an image
wordcloud.to_file("wordcloud.png")

print("WordCloud image saved as 'wordcloud.png'.")
# Out:
# WordCloud image saved as 'wordcloud.png'.
